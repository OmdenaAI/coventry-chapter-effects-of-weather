# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('allukcities.csv')

# %%
df.shape
# Out:
# (4, 12)

# %%
df
# Out:
#   Quarter  London  North East  North West  East Midlands  West Midlands  \
# 0      Q1   174.0        96.0       298.0          156.0          226.0
# 1      Q2   193.0       147.0       293.0          134.0          208.0
# 2      Q3   169.0       139.0       298.0          154.0          213.0
# 3      Q4   199.0       139.0       321.0          168.0          246.0
#
#    East of England  South East  South West  Yorkshire and The Humber  England  \
# 0            146.0       248.0       147.0                     193.0   1684.0
# 1            137.0       230.0       163.0                     197.0   1702.0
# 2            136.0       240.0       187.0                     199.0   1735.0
# 3            149.0       268.0       152.0                     211.0   1853.0
#
#    Wales
# 0  123.0
# 1  107.0
# 2  100.0
# 3  108.0

# %%
for col in df.select_dtypes(exclude='object'):
    sns.barplot(x = 'Quarter', y = col, data= df)
    plt.title(col)
    plt.show()
